# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249700 entries, 0 to 249699
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    249700 non-null  float64
#  1   V1      249700 non-null  float64
#  2   V2      249700 non-null  float64
#  3   V3      249700 non-null  float64
#  4   V4      249700 non-null  float64
#  5   V5      249700 non-null  float64
#  6   V6      249700 non-null  float64
#  7   V7      249700 non-null  float64
#  8   V8      249700 non-null  float64
#  9   V9      249700 non-null  float64
#  10  V10     249700 non-null  float64
#  11  V11     249700 non-null  float64
#  12  V12     249700 non-null  float64
#  13  V13     249700 non-null  float64
#  14  V14     249700 non-null  float64
#  15  V15     249700 non-null  float64
#  16  V16     249700 non-null  float64
#  17  V17     249699 non-null  float64
#  18  V18     249699 non-null  float64
#  19  V19     249699 non-null  float64
# ...

# %%
df.describe().transpose()
# Out:
#            count          mean           std        min           25%  \
# Time    249700.0  85241.988819  42724.687089   0.000000  50261.000000
# V1      249700.0     -0.037522      1.960261 -56.407510     -0.936401
# V2      249700.0     -0.020251      1.670219 -72.715728     -0.608873
# V3      249700.0      0.102186      1.507213 -33.680984     -0.714822
# V4      249700.0      0.024710      1.415133  -5.683171     -0.837259
# V5      249700.0     -0.037821      1.376181 -42.147898     -0.728067
# V6      249700.0      0.018839      1.326691 -26.160506     -0.747813
# V7      249700.0     -0.016514      1.227380 -43.557242     -0.565173
# V8      249700.0      0.001950      1.195252 -73.216718     -0.201575
# V9      249700.0      0.001142      1.112230 -13.434066     -0.655004
# V10     249700.0     -0.000930      1.087371 -24.588262     -0.526639
# V11     249700.0      0.041673      1.029329  -4.797473     -0.719284
# ...

# %%
df["Class"].value_counts()
# Out:
# 0.0    249243
# 1.0       456
# Name: Class, dtype: int64

# %%
normal_cases = df[df["Class"]==0]

# %%
normal_cases.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
normal_cases.describe().transpose()
# Out:
#            count          mean           std        min           25%  \
# Time    249243.0  85261.520693  42720.141584   0.000000  50280.500000
# V1      249243.0     -0.028318      1.927589 -56.407510     -0.932844
# V2      249243.0     -0.027196      1.653439 -72.715728     -0.609983
# V3      249243.0      0.115611      1.442032 -33.680984     -0.708444
# V4      249243.0      0.016344      1.397384  -5.683171     -0.838844
# V5      249243.0     -0.031604      1.349805 -42.147898     -0.725948
# V6      249243.0      0.021396      1.324116 -26.160506     -0.746137
# V7      249243.0     -0.005810      1.160603 -31.764946     -0.562738
# V8      249243.0      0.000829      1.157870 -73.216718     -0.201576
# V9      249243.0      0.005928      1.102228  -6.290730     -0.652056
# V10     249243.0      0.009812      1.037320 -14.741096     -0.524394
# V11     249243.0      0.034591      1.010273  -4.797473     -0.720565
# ...

# %%
fraud_cases = df[df["Class"]==1]

# %%
fraud_cases.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
fraud_cases.describe().transpose()
# Out:
#         count          mean           std         min           25%  \
# Time    456.0  74414.186404  43794.009574  406.000000  41159.750000
# V1      456.0     -5.066354      6.931632  -30.552380     -6.616772
# V2      456.0      3.772761      4.347729   -7.449015      1.264308
# V3      456.0     -7.234048      7.317535  -31.103685     -9.525072
# V4      456.0      4.600891      2.885450   -1.313275      2.423996
# V5      456.0     -3.439850      5.446294  -22.105532     -5.082673
# V6      456.0     -1.375926      1.884236   -6.406267     -2.513816
# V7      456.0     -5.870953      7.378686  -43.557242     -8.821237
# V8      456.0      0.614649      7.017373  -41.044261     -0.195336
# V9      456.0     -2.612230      2.552449  -13.434066     -3.876397
# V10     456.0     -5.869357      4.985879  -24.588262     -8.104580
# V11     456.0      3.916202      2.697587   -1.702228      2.108974
# V12     456.0     -6.471634      4.715408  -18.683715     -9.033521
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df[df['V17'].isnull()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 249699  154537.0 -1.108766  1.427286 -0.599176 -1.464288  1.663714 -1.248192
#
#               V7        V8        V9  ...  V21  V22  V23  V24  V25  V26  V27  \
# 249699  1.741368  0.014242 -1.254061  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#         V28  Amount  Class
# 249699  NaN     NaN    NaN
#
# [1 rows x 31 columns]

# %%
df = df.drop(249699, axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249699 entries, 0 to 249698
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    249699 non-null  float64
#  1   V1      249699 non-null  float64
#  2   V2      249699 non-null  float64
#  3   V3      249699 non-null  float64
#  4   V4      249699 non-null  float64
#  5   V5      249699 non-null  float64
#  6   V6      249699 non-null  float64
#  7   V7      249699 non-null  float64
#  8   V8      249699 non-null  float64
#  9   V9      249699 non-null  float64
#  10  V10     249699 non-null  float64
#  11  V11     249699 non-null  float64
#  12  V12     249699 non-null  float64
#  13  V13     249699 non-null  float64
#  14  V14     249699 non-null  float64
#  15  V15     249699 non-null  float64
#  16  V16     249699 non-null  float64
#  17  V17     249699 non-null  float64
#  18  V18     249699 non-null  float64
#  19  V19     249699 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
sns.heatmap(df.corr())

# %%
sns.heatmap(normal_cases.corr())

# %%
sns.heatmap(fraud_cases.corr())

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("Class", axis = 1)
y = df["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=101)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.metrics import plot_confusion_matrix, classification_report

# %%
log = LogisticRegression(max_iter=10000000)
tree = DecisionTreeClassifier()
forest = RandomForestClassifier()
ada = AdaBoostClassifier()
grad = GradientBoostingClassifier()

# %%
def run_model(model, X_train, y_train, X_test, y_test):
  model.fit(X_train, y_train)
  model_preds = model.predict(X_test)
  print(classification_report(y_test, model_preds))
  print()
  plot_confusion_matrix(model, X_test, y_test)
  print()

# %%
run_model(log, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.86      0.59      0.70       138
#
#     accuracy                           1.00     74910
#    macro avg       0.93      0.80      0.85     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(tree, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.74      0.79      0.76       138
#
#     accuracy                           1.00     74910
#    macro avg       0.87      0.89      0.88     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(forest, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.91      0.76      0.83       138
#
#     accuracy                           1.00     74910
#    macro avg       0.96      0.88      0.91     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(ada, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.87      0.69      0.77       138
#
#     accuracy                           1.00     74910
#    macro avg       0.94      0.84      0.88     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(grad, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.77      0.35      0.48       138
#
#     accuracy                           1.00     74910
#    macro avg       0.89      0.67      0.74     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
log_param_grid = {"penalty":["l1", "l2", "elasticnet"], 
                  "l1_ratio": np.linspace(0,1,20), 
                  "C": np.logspace(0,10,20)}
tree_param_grid = {"min_samples_split": [2,3,4,5], 
                   "max_depth": [2,3,4,5], 
                   "criterion":['gini', 'entropy']}
forest_param_grid = {"n_estimators": [64, 100, 128, 200], 
                     "max_features": [2, 3, 4],
                     "bootstrap": [True, False], 
                     "oob_score": [True, False]}
ada_param_grid = {"n_estimators": [50,100,150], 
                  "learning_rate": [0.1, 0.05, 0.2]}
grad_param_grid = {"n_estimators": [50,100,150], 
                    "learning_rate": [0.1, 0.05, 0.2],
                    "max_depth": [3,4,5]}

# %%
log_grid_model = GridSearchCV(log, log_param_grid)
tree_grid_model = GridSearchCV(tree, tree_param_grid)
forest_grid_model = GridSearchCV(forest, forest_param_grid)
ada_grid_model = GridSearchCV(ada, ada_param_grid)
grad_grid_model = GridSearchCV(grad, grad_param_grid)

# %%
log_grid_model.fit(X_train, y_train)

# %%
log_grid_model.best_params_

# %%
tree_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5],
#                          'min_samples_split': [2, 3, 4, 5]})

# %%
tree_grid_model.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2}

# %%
forest_grid_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py", line 411, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
# ...

# %%
forest_grid_model.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 4,
#  'n_estimators': 128,
#  'oob_score': False}

# %%
ada_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=AdaBoostClassifier(),
#              param_grid={'learning_rate': [0.1, 0.05, 0.2],
#                          'n_estimators': [50, 100, 150]})

# %%
ada_grid_model.best_params_
# Out:
# {'learning_rate': 0.2, 'n_estimators': 150}

# %%
grad_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.05, 0.2],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [50, 100, 150]})

# %%
grad_grid_model.best_params_

# %%
log = LogisticRegression(C = 10, penalty = "l2", max_iter=10000000)
tree = DecisionTreeClassifier(max_depth=5, min_samples_split=2, criterion="gini")
forest = RandomForestClassifier(n_estimators=128, max_features=4, bootstrap=False, oob_score = False)
ada = AdaBoostClassifier(learning_rate=0.2, n_estimators=150)
grad = GradientBoostingClassifier(learning_rate=0.2, n_estimators=150, max_depth=3)

# %%
run_model(log, X_train, y_train, X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1479: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   "(penalty={})".format(self.penalty)
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.86      0.61      0.71       138
#
#     accuracy                           1.00     74910
#    macro avg       0.93      0.80      0.86     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(tree, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.84      0.74      0.78       138
#
#     accuracy                           1.00     74910
#    macro avg       0.92      0.87      0.89     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(forest, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.93      0.78      0.85       138
#
#     accuracy                           1.00     74910
#    macro avg       0.97      0.89      0.92     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(ada, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.84      0.72      0.77       138
#
#     accuracy                           1.00     74910
#    macro avg       0.92      0.86      0.89     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
run_model(grad, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     74772
#          1.0       0.72      0.28      0.40       138
#
#     accuracy                           1.00     74910
#    macro avg       0.86      0.64      0.70     74910
# weighted avg       1.00      1.00      1.00     74910
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
final_model = RandomForestClassifier(n_estimators=128, max_features=4, bootstrap=False, oob_score = False)

# %%
final_model.fit(X,y)

# %%
import joblib

# %%
joblib.dump(final_model, "final_model.pkl")

# %%
joblib.dump(list(X.columns), "column_names.pkl")
